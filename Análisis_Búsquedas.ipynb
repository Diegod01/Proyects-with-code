# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
# !pip install pytrends

# %%
trends.build_payload(kw_list=["AI"])
data = trends.interest_by_region()
data = data.sort_values(by="AI", ascending=False)
data = data.head(10)
print(data)
# Out:
#               AI
# geoName
# Vietnam      100
# Romania       59
# Italy         48
# China         29
# Moldova       26
# Singapore     16
# South Korea   15
# Hong Kong     13
# Taiwan        13
# Brazil        12

# %%
#La mayoría de búsquedas de "IA" vienen de Vietnam

# %%
#Vamos a visualizarlo en forma de gráfica

# %%
data.reset_index().plot(x="geoName", y="AI", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['AI'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['AI'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for AI', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
data['AI'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for AI', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
